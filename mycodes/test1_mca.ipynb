# %% [markdown]
# ##  Mathematica Jupyter Notebook test

# %%
Print["Hello Peace World"]
# Out:
# Hello Peace World

# %%
Print[38.0]
# Out:
# 38.

# %%
Plot[Sin[x],{x,0,3},PlotStyle->RGB[0,1,0]]
# Out:
# -Graphics-

# %%
Plot3D[Sin[x*y],{x,0,3},{y,0,4},PlotStyle->Blue]
# Out:
# -Graphics3D-

# %%
(* feq1=Function[x, x+1]; *)
feq1=Function[x,x-x^3/3!+x^5/5! ];
x=Range[0,Pi,0.1]; 
ListPlot[feq1[x]]
# Out:
# -Graphics-
